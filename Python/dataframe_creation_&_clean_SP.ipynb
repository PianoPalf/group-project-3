# %% [markdown]
# # PyHack - Setup DataFrame

# %% [markdown]
# ## Import Dependencies

# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import matplotlib as mpl
import seaborn as sns

# Set DPI of all Plots
plt.rcParams["figure.dpi"] = 150

# Set Dark Grid for all Plots
sns.set_style('darkgrid')

# File to Load
data_breaches_csv = Path("../Resources/balloon_race_data_breaches.csv")
data_breaches_countries_csv = Path("../Resources/databreach_country_coords.xls")

# %% [markdown]
# ## Import Data to Pandas DataFrames

# %%
# Import Data from CSV files as Pandas DataFrames
dBreaches_df = pd.read_csv(data_breaches_csv)
dBreaches_location_df = pd.read_excel(data_breaches_countries_csv)

# %%
# Print the First 3 Rows of dBreaches DataFrame
dBreaches_df.head(3)
# Out:
#       organisation alternative name records lost  year       date  \
# 0             Plex              NaN   15,000,000     2022  Aug-22
# 1          Twitter              NaN    5,400,000     2021  Dec-21
# 2  Shanghai Police              NaN  500,000,000     2022  Jul-22
#
#                                                story     sector  method  \
# 0  Intruders access password data, usernames, and...       web   hacked
# 1  Zero day vulnerability allowed a threat actor ...        web  hacked
# 2  A database containing records of over a billio...  financial  hacked
#
#   interesting story  data sensitivity displayed records  Unnamed: 11  \
# 0               NaN               1.0               NaN          NaN
# 1               NaN               2.0               NaN          NaN
# 2               NaN               5.0     "one billion"          NaN
#
#          source name                                    1st source link  \
# 0       Ars technica  https://arstechnica.com/information-technology...
# 1  Bleeping Computer  https://www.bleepingcomputer.com/news/security...
# 2       The Register  https://www.theregister.com/2022/07/05/shangha...
#
#   2nd source link   ID
# 0             NaN  418
# 1             NaN  419
# 2             NaN  420

# %%
# Print the First 3 Rows of dBreaches_location DataFrame
dBreaches_location_df.head(3)
# Out:
#       organisation           Location, Latitude, Longitude
# 0             Plex      Los Gatos, USA, 37.2350, -121.9629
# 1          Twitter  San Francisco, USA, 37.7749, -122.4194
# 2  Shanghai Police      Shanghai, China, 31.2304, 121.4737

# %% [markdown]
# ## Clean dBreaches_location_df

# %%
# Split the single Column by comma to extract City, Country, Latitude and Longitude
dBreaches_location_df[['city', 'country', 'latitude', 'longitude']] = dBreaches_location_df['Location, Latitude, Longitude'].str.split(',', expand=True)

# %%
# Drop the Combined Column
dBreaches_location_df = dBreaches_location_df.drop('Location, Latitude, Longitude', axis=1)

# %%
# Drop Duplicate Rows from dBreaches_location_df
dBreaches_location_df = dBreaches_location_df.drop_duplicates()

# %%
# Strip preceding white space from dBreaches_location_df
dBreaches_location_df['latitude'] = dBreaches_location_df['latitude'].str.strip()
# Strip preceding white space from dBreaches_location_df
dBreaches_location_df['longitude'] = dBreaches_location_df['longitude'].str.strip()

# %%
# Drop Rows lacking Latitude value
dBreaches_location_df = dBreaches_location_df[dBreaches_location_df["latitude"].str.contains("N/A") == False]

# %%
# Change latitude and longitude Column to integer data type
dBreaches_location_df['latitude'] = dBreaches_location_df['latitude'].astype(float)
dBreaches_location_df['longitude'] = dBreaches_location_df['longitude'].astype(float)

# %%
# Check DataFrame
dBreaches_location_df
# Out:
#                    organisation           city country   latitude   longitude
# 0                          Plex      Los Gatos     USA  37.235000 -121.962900
# 1                       Twitter  San Francisco     USA  37.774900 -122.419400
# 2               Shanghai Police       Shanghai   China  31.230400  121.473700
# 3      City of Amagasaki, Japan      Amagasaki   Japan  34.730300  135.579500
# 5                        Heroku  San Francisco     USA  37.774900 -122.419400
# ..                          ...            ...     ...        ...         ...
# 410   Automatic Data Processing       Roseland     USA  40.820100  -74.302400
# 411                        KDDI          Tokyo   Japan  35.682839  139.759455
# 412             Hewlett Packard      Palo Alto     USA  37.441900 -122.143000
# 413             Ameritrade Inc.          Omaha     USA  41.256500  -95.934500
# 415  Cardsystems Solutions Inc.        Atlanta     USA  33.749000  -84.388000
#
# [333 rows x 5 columns]

# %%
# Create Coordinates Column for GeoJSON Compatibility
dBreaches_location_df['coordinates'] = dBreaches_location_df[['latitude', 'longitude']].apply(list, axis=1)

# %%
# Check Unique Countries
dBreaches_location_df['country'].unique()
# Out:
# array([' USA', ' China', ' Japan', ' Sri Lanka', ' Russia',
#        ' Switzerland', ' Canada', ' Indonesia', ' Taiwan',
#        ' United Kingdom', ' South Africa', ' India', ' Estonia',
#        ' Germany', ' Brazil', ' France', ' Italy', ' Sweden',
#        ' Netherlands', ' Israel', ' Australia', ' Bulgaria',
#        ' South Korea', ' Singapore', ' Hong Kong', ' Belgium', ' USA.',
#        ' United Arab Emirates', ' Norway', ' Panama', ' Philippines',
#        ' Syria', " United Arab Emirates (although it's developed by)",
#        ' Luxembourg', " USA (Experian's North American headquarters)",
#        ' Serbia', ' Turkey', ' Greece', ' Puerto Rico', ' Chile'],
#       dtype=object)

# %%
# Strip preceding white space from each Country
dBreaches_location_df['country'] = dBreaches_location_df['country'].str.strip()

# %%
# Correct Country List
dBreaches_location_df['country'] = dBreaches_location_df['country'].replace("USA (Experian's North American headquarters)", 'USA')
dBreaches_location_df['country'] = dBreaches_location_df['country'].replace('USA.', 'USA')
dBreaches_location_df['country'] = dBreaches_location_df['country'].replace("United Arab Emirates (although it's developed by)", 'United Arab Emirates')

# %%
# Check Unique Cities
dBreaches_location_df['city'].unique()
# Out:
# array(['Los Gatos', 'San Francisco', 'Shanghai', 'Amagasaki', 'Atlanta',
#        'Colombo', 'Novosibirsk', 'Olympia', 'Geneva', 'Calgary', 'Tokyo',
#        'Menlo Park', 'Scottsdale', 'Jakarta', 'New Taipei City', 'Ellon',
#        'Santa Clara', 'Johannesburg', 'Chennai', 'Seattle', 'Tampa',
#        'Dallas', 'Sammamish', 'Bellevue', 'Tallinn', 'Chichester',
#        'Sunnyvale', 'Wolfsburg', 'Chicago', 'New Delhi', 'New York City',
#        'Denver', 'São Paulo', 'Philadelphia', 'Frankfurt', 'Paris',
#        'Manchester', 'Austin', 'Rome', 'Stockholm', 'Boston',
#        'Lake Worth', 'Santa Monica', 'Shenzhen', 'Kyoto', 'Arlington',
#        'London', 'Redmond', 'The Hague', 'Hook', 'Nottingham',
#        'Welwyn Garden City', 'Bethesda', 'San Jose', 'Jerusalem',
#        'Las Vegas', 'Regensburg', 'Wawa', 'Lévis', 'Washington',
#        'Secaucus', 'Canberra', 'Sydney', 'Mumbai', 'Toyota City',
#        'Palo Alto', 'Los Angeles', 'Berlin', 'Irvine', 'Moscow',
#        'Gurugram', 'Israel', 'Bellingham', 'Miami', 'Toronto', 'Sofia',
#        'McLean', 'Seoul', 'Lake Mary', 'Singapore', 'Tallahassee',
#        'Hong Kong', 'Mountain View', 'Brussels', 'St. Louis', 'Or Yehuda',
#        'Dubai', 'Baltimore', 'Oslo', 'Cologne', 'Beverly Hills',
#        'Round Rock', 'Milan', 'City of Industry', 'Petah Tikva',
#        'Borlänge', 'Montreal', 'Vancouver', 'Panama City', 'Manila',
#        'Damascus', 'Phoenix', 'Carpinteria', 'Dublin', 'Saint Petersburg',
#        'Maidenhead', 'Melbourne', 'Campbell', 'Luxembourg', 'Yuba City',
#        'Mountlake Terrace', 'Sharjah', 'Carrollton', 'Costa Mesa',
#        'Indianapolis', 'Franklin', 'Belgrade', 'Culver City',
#        'Bloomington', 'Istanbul', 'Framingham', 'Hainan', 'Newark',
#        'Poughkeepsie', 'Deerfield', 'Downers Grove', 'Roubaix',
#        'Cupertino', 'Montreuil', 'Fort Meade', 'Redwood City',
#        'Cedar Rapids', 'Portland', 'Oklahoma City', 'Newbury',
#        'Minneapolis', 'Beijing', 'Columbia', 'Sacramento', 'Binghamton',
#        'Hollywood', 'Hamburg', 'Athens', 'New Hampshire',
#        'South Weymouth', 'New Haven', 'Irving', 'San Mateo', 'Milwaukee',
#        'Rockville', 'Stamford', 'Rancho Mirage', 'Spartanburg',
#        'San Diego', 'Markham', 'Salem', 'College Point', 'Jacksonville',
#        'Chattanooga', 'San Juan', 'Columbus', 'Lafayette', 'Bronx',
#        'Cleveland', 'Princeton', 'Norcross', 'Richmond', 'Berkeley',
#        'Birmingham', 'Scarborough', 'Coral Gables', 'Calabasas',
#        'Stanford', 'Salt Lake City', 'Santiago', 'Bonn', 'United Kingdom',
#        'Weston', 'Bristol', 'Omaha', 'Roseland'], dtype=object)

# %%
# Check City Value Counts
dBreaches_location_df['city'].value_counts()
# Out:
# New York City    22
# London           21
# San Francisco    18
# Atlanta           9
# Tokyo             8
#                  ..
# Toyota City       1
# Mumbai            1
# Sydney            1
# Secaucus          1
# Roseland          1
# Name: city, Length: 181, dtype: int64

# %%
# Drop Rows containing non-city names in City Column
dBreaches_location_df = dBreaches_location_df[dBreaches_location_df["city"].str.contains("No State/Country Info found") == False]
dBreaches_location_df = dBreaches_location_df[dBreaches_location_df["city"].str.contains("No specific headquarters") == False]

# %%
# Check Data Types
dBreaches_location_df.dtypes
# Out:
# organisation     object
# city             object
# country          object
# latitude        float64
# longitude       float64
# coordinates      object
# dtype: object

# %%
# Check for NaNs
dBreaches_location_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 415
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   organisation  333 non-null    object
#  1   city          333 non-null    object
#  2   country       333 non-null    object
#  3   latitude      333 non-null    float64
#  4   longitude     333 non-null    float64
#  5   coordinates   333 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 18.2+ KB

# %% [markdown]
# ## Clean dBreaches_df

# %%
# Standardise Header Row
dBreaches_df.columns = dBreaches_df.columns.str.lower()

# %%
# Check Column Headers
dBreaches_df.columns
# Out:
# Index(['organisation', 'alternative name', 'records lost', 'year   ', 'date',
#        'story', 'sector', 'method', 'interesting story', 'data sensitivity',
#        'displayed records', 'unnamed: 11', 'source name', '1st source link',
#        '2nd source link', 'id'],
#       dtype='object')

# %%
# Drop Duplicates Rows from dBreaches_df
dBreaches_df = dBreaches_df.drop_duplicates()

# %%
# Drop id Column
dBreaches_df = dBreaches_df.drop('id', axis=1)

# %%
# Create New Unique id Column
dBreaches_df['id'] = range(1, len(dBreaches_df) + 1)

# %%
# Drop unnamed Column
dBreaches_df = dBreaches_df.drop('unnamed: 11', axis=1)

# Split date Column to extract Month
dBreaches_df[['date', 'temp']] = dBreaches_df['date'].str.split('-', expand=True)

# Split sector Column to separate into sector and secondary sector
dBreaches_df[['sector', 'secondary sector']] = dBreaches_df['sector'].str.split(',', expand=True)

# %%
# Drop Temporary Column
dBreaches_df = dBreaches_df.drop('temp', axis=1)

# Drop 2nd source link Column
dBreaches_df = dBreaches_df.drop('2nd source link', axis=1)

# Rename date Column
dBreaches_df = dBreaches_df.rename(columns={"date": "month"})

# Rename 'year   ' Column
dBreaches_df = dBreaches_df.rename(columns={"year   ": "year"})

# Rename 1st source link Column
dBreaches_df = dBreaches_df.rename(columns={"1st source link": "source link"})

# Replace oops! text in method Column
dBreaches_df['method'] = dBreaches_df['method'].replace('oops!', 'accident')

# Remove spaces from sector Column
dBreaches_df['sector'] = dBreaches_df['sector'].str.replace(' ', '')

# %%
# Remove all Digits from month Column
dBreaches_df['month'] = dBreaches_df['month'].str.replace('\d+', '')
# Out:
# /var/folders/_6/tq2832l10c75gwmjp1dpv9bw0000gn/T/ipykernel_37857/2835065297.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dBreaches_df['month'] = dBreaches_df['month'].str.replace('\d+', '')

# %%
# Check Column Headers
dBreaches_df.columns
# Out:
# Index(['organisation', 'alternative name', 'records lost', 'year', 'month',
#        'story', 'sector', 'method', 'interesting story', 'data sensitivity',
#        'displayed records', 'source name', 'source link', 'id',
#        'secondary sector'],
#       dtype='object')

# %%
# Reorder and Drop Columns 
dBreaches_df = dBreaches_df[['id', 'organisation', 'records lost', 'month', 'year',\
                             'sector', 'method', 'data sensitivity', 'source name']]

# %%
# Replace Spaces between words in Column names with underscores
dBreaches_df.columns = dBreaches_df.columns.str.replace(' ', '_', regex=True)

# %%
# Check Structure of DataFrame
dBreaches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 416
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                417 non-null    int64
#  1   organisation      417 non-null    object
#  2   records_lost      417 non-null    object
#  3   month             417 non-null    object
#  4   year              417 non-null    int64
#  5   sector            417 non-null    object
#  6   method            417 non-null    object
#  7   data_sensitivity  416 non-null    float64
#  8   source_name       417 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 32.6+ KB

# %%
# Drop Rows containing NaNs from Merged DataFrame
dBreaches_df = dBreaches_df.dropna()

# %%
# Check Data Types of Each Column
dBreaches_df.dtypes
# Out:
# id                    int64
# organisation         object
# records_lost         object
# month                object
# year                  int64
# sector               object
# method               object
# data_sensitivity    float64
# source_name          object
# dtype: object

# %%
# Remove Non-Digit Characters in 'records lost' Column
dBreaches_df['records_lost'] = dBreaches_df['records_lost'].str.replace(r'\D+', '')
# Out:
# /var/folders/_6/tq2832l10c75gwmjp1dpv9bw0000gn/T/ipykernel_37857/948398820.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dBreaches_df['records_lost'] = dBreaches_df['records_lost'].str.replace(r'\D+', '')

# %%
# Change 'records lost' and 'data sensitivity' Columns to integer data type
dBreaches_df['records_lost'] = dBreaches_df['records_lost'].astype(int)
dBreaches_df['data_sensitivity'] = dBreaches_df['data_sensitivity'].astype(int)

# %%
# Check Data Types of Each Column again
dBreaches_df.dtypes
# Out:
# id                   int64
# organisation        object
# records_lost         int64
# month               object
# year                 int64
# sector              object
# method              object
# data_sensitivity     int64
# source_name         object
# dtype: object

# %%
# Check Data Breach Method Column
dBreaches_df['method'].unique()
# Out:
# array(['hacked', 'accident', 'inside job', 'poor security ',
#        'poor security', 'lost device', 'lost device '], dtype=object)

# %%
# Remove White Space from method Column
dBreaches_df['method'] = dBreaches_df['method'].str.strip()

# %%
# Check DataFrame
dBreaches_df
# Out:
#       id                 organisation  records_lost  month  year      sector  \
# 0      1                         Plex      15000000    Aug  2022         web
# 1      2                      Twitter       5400000    Dec  2021         web
# 2      3              Shanghai Police     500000000    Jul  2022   financial
# 3      4     City of Amagasaki, Japan        500000    Jun  2022  government
# 4      5       Dubai Real Estate Leak        800000    May  2022   financial
# ..   ...                          ...           ...    ...   ...         ...
# 412  413              Hewlett Packard        200000   Mar   2006        tech
# 413  414              Ameritrade Inc.        200000   Apr   2005     finance
# 414  415                    Citigroup       3900000   Jun   2005     finance
# 415  416  Cardsystems Solutions Inc.       40000000   Jun   2005     finance
# 416  417                          AOL      92000000   Jun   2004         web
#
#           method  data_sensitivity        source_name
# 0         hacked                 1       Ars technica
# 1         hacked                 2  Bleeping Computer
# 2         hacked                 5       The Register
# 3       accident                 3                BBC
# 4     inside job                 1                E24
# ..           ...               ...                ...
# 412  lost device                 2    Computer Weekly
# 413  lost device                 2                NBC
# 414  lost device                 3           NY Times
# 415       hacked                 3              Wired
# 416   inside job                 1                CNN
#
# [416 rows x 9 columns]

# %% [markdown]
# ## Merge DataFrames

# %%
# Merge DataFrames
merged_dBreaches_df = dBreaches_df.merge(dBreaches_location_df,on=['organisation'])

# %%
# Check Merged DataFrame
merged_dBreaches_df.head()
# Out:
#     id     organisation  records_lost  month  year     sector         method  \
# 0    1             Plex      15000000    Aug  2022        web         hacked
# 1    2          Twitter       5400000    Dec  2021        web         hacked
# 2  148          Twitter     330000000   May   2018       tech  poor security
# 3  273          Twitter        250000   Feb   2013        web         hacked
# 4    3  Shanghai Police     500000000    Jul  2022  financial         hacked
#
#    data_sensitivity        source_name           city country  latitude  \
# 0                 1       Ars technica      Los Gatos     USA   37.2350
# 1                 2  Bleeping Computer  San Francisco     USA   37.7749
# 2                 1            Reuters  San Francisco     USA   37.7749
# 3                 1                CNN  San Francisco     USA   37.7749
# 4                 5       The Register       Shanghai   China   31.2304
#
#    longitude           coordinates
# 0  -121.9629   [37.235, -121.9629]
# 1  -122.4194  [37.7749, -122.4194]
# 2  -122.4194  [37.7749, -122.4194]
# 3  -122.4194  [37.7749, -122.4194]
# 4   121.4737   [31.2304, 121.4737]

# %%
# Drop Rows containing NaNs from Merged DataFrame
cleaned_dBreaches_df = merged_dBreaches_df.dropna()

# %%
# Drop Duplicate Rows
cleaned_dBreaches_df = cleaned_dBreaches_df.drop_duplicates(subset=['id'])

# %%
# Remove White Space from 'month' Column
cleaned_dBreaches_df['month'] = cleaned_dBreaches_df['month'].str.strip()

# %%
# Create a dictionary to map three-letter month abbreviations to numbers
month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

# Use the map method to apply the mapping to the 'Month' column
cleaned_dBreaches_df['month_digit'] = cleaned_dBreaches_df['month'].map(month_mapping)

# %%
cleaned_dBreaches_df['month'].unique()
# Out:
# array(['Aug', 'Dec', 'May', 'Feb', 'Jul', 'Jun', 'Apr', 'Mar', 'Jan',
#        'Nov', 'Oct', 'Sep'], dtype=object)

# %%
# Combine 'year' and 'month_digit' columns into a single 'date' column as strings
cleaned_dBreaches_df['date'] = cleaned_dBreaches_df['year'].astype(str) + '-' + cleaned_dBreaches_df['month_digit'].astype(str) + '-01'

# Convert the 'Date' column to a datetime column
cleaned_dBreaches_df['date'] = pd.to_datetime(cleaned_dBreaches_df['date'], format='%Y-%m-%d')

# %%
# Drop 'month_digit' Column
cleaned_dBreaches_df = cleaned_dBreaches_df.drop('month_digit', axis=1)

# %%
# Check Cleaned Merged DataFrame
cleaned_dBreaches_df
# Out:
#       id               organisation  records_lost month  year      sector  \
# 0      1                       Plex      15000000   Aug  2022         web
# 1      2                    Twitter       5400000   Dec  2021         web
# 2    148                    Twitter     330000000   May  2018        tech
# 3    273                    Twitter        250000   Feb  2013         web
# 4      3            Shanghai Police     500000000   Jul  2022   financial
# ..   ...                        ...           ...   ...   ...         ...
# 344  410     US Dept of Vet Affairs      26500000   Jul  2006  government
# 345  411  Automatic Data Processing        125000   Jul  2006     finance
# 346  412                       KDDI       4000000   Jun  2006    telecoms
# 347  413            Hewlett Packard        200000   Mar  2006        tech
# 348  414            Ameritrade Inc.        200000   Apr  2005     finance
#
#             method  data_sensitivity        source_name           city  \
# 0           hacked                 1       Ars technica      Los Gatos
# 1           hacked                 2  Bleeping Computer  San Francisco
# 2    poor security                 1            Reuters  San Francisco
# 3           hacked                 1                CNN  San Francisco
# 4           hacked                 5       The Register       Shanghai
# ..             ...               ...                ...            ...
# 344    lost device                 2        GCN, US Gov     Washington
# 345  poor security                 2           ABC News       Roseland
# 346         hacked                 1     Computer World          Tokyo
# 347    lost device                 2    Computer Weekly      Palo Alto
# 348    lost device                 2                NBC          Omaha
#
#     country   latitude   longitude              coordinates       date
# 0       USA  37.235000 -121.962900      [37.235, -121.9629] 2022-08-01
# 1       USA  37.774900 -122.419400     [37.7749, -122.4194] 2021-12-01
# 2       USA  37.774900 -122.419400     [37.7749, -122.4194] 2018-05-01
# 3       USA  37.774900 -122.419400     [37.7749, -122.4194] 2013-02-01
# 4     China  31.230400  121.473700      [31.2304, 121.4737] 2022-07-01
# ..      ...        ...         ...                      ...        ...
# 344     USA  47.751100 -120.740100     [47.7511, -120.7401] 2006-07-01
# 345     USA  40.820100  -74.302400      [40.8201, -74.3024] 2006-07-01
# 346   Japan  35.682839  139.759455  [35.682839, 139.759455] 2006-06-01
# 347     USA  37.441900 -122.143000      [37.4419, -122.143] 2006-03-01
# 348     USA  41.256500  -95.934500      [41.2565, -95.9345] 2005-04-01
#
# [344 rows x 15 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Method Value Count
method_count = cleaned_dBreaches_df['method'].value_counts()
method_count
# Out:
# hacked           234
# lost device       43
# poor security     34
# accident          18
# inside job        15
# Name: method, dtype: int64

# %%
# Records Lost by Data Breach Methods
methods_groupby = cleaned_dBreaches_df.groupby(['method'])['records_lost'].describe()
methods_groupby
# Out:
#                count          mean           std      min        25%  \
# method
# accident        18.0  4.447413e+06  6.785052e+06     30.0   500000.0
# hacked         234.0  3.651033e+07  9.757621e+07   1025.0   625000.0
# inside job      15.0  1.059109e+07  2.316554e+07  89000.0  1250000.0
# lost device     43.0  3.085624e+06  5.905809e+06  34000.0   170055.5
# poor security   34.0  7.204000e+07  1.332548e+08  50000.0   925000.0
#
#                      50%         75%          max
# method
# accident       2200000.0   5142797.0   24000000.0
# hacked         4500000.0  23500000.0  700000000.0
# inside job     2500000.0   8568702.5   92000000.0
# lost device     800000.0   3150000.0   26500000.0
# poor security  5750000.0  51625000.0  550000000.0

# %%
# Sector Value Count
sector_count = cleaned_dBreaches_df['sector'].value_counts()
sector_count
# Out:
# web           88
# health        37
# retail        36
# government    35
# finance       34
# tech          21
# telecoms      18
# app           16
# transport     15
# gaming        15
# misc          11
# academic      11
# financial      4
# NGO            1
# legal          1
# military       1
# Name: sector, dtype: int64

# %%
# Data sensitivity Value Count
data_sensitivity_count = cleaned_dBreaches_df['data_sensitivity'].value_counts()
data_sensitivity_count
# Out:
# 1    110
# 2    108
# 3     58
# 4     47
# 5     21
# Name: data_sensitivity, dtype: int64

# %%
# Check the Most Serious Data Breaches (i.e Data Sensitivity of 5)
serious_breaches = cleaned_dBreaches_df.loc[cleaned_dBreaches_df['data_sensitivity'] == 5]
serious_breaches
# Out:
#       id                                    organisation  records_lost month  \
# 4      3                                 Shanghai Police     500000000   Jul
# 29    30                                            Epik      15000000   Sep
# 61    58                                        GEDmatch       1400000   Sep
# 87    87                                      Vårdguiden       2700000   Feb
# 113  115                                         Suprema      27800000   Aug
# 135  142                                        Firebase     100000000   Jun
# 157  173                        Swedish Transport Agency       3000000   Jul
# 168  190                                 Mossack Fonseca      11500000   Apr
# 169  191            Philippines’ Commission on Elections      55000000   Apr
# 178  204                  Mutuelle Generale de la Police        112000   Jun
# 190  218                                       ClixSense       6600000   Sep
# 192  221                                         Premera      11000000   Mar
# 196  227                                           VTech       6400000   Dec
# 197  228                                    Hacking Team        500000   Jul
# 199  230  US Office of Personnel Management (2nd Breach)      21500000   Jul
# 204  236                            Securus Technologies      70000000   Nov
# 228  260                             Korea Credit Bureau      20000000   Jan
# 249  283                        National Security Agency       1500000   Jun
# 277  323             South Shore Hospital, Massachusetts        800000   Sep
# 323  386                                    RBS Worldpay       1500000   Dec
# 331  395                          UK Ministry of Defence       1700000   Oct
#
#      year      sector         method  data_sensitivity        source_name  \
# 4    2022   financial         hacked                 5       The Register
# 29   2021      retail         hacked                 5       Ars Technica
# 61   2020        misc         hacked                 5     New York Times
# 87   2019      health  poor security                 5     ComputerSweden
# 113  2019        tech  poor security                 5           Guardian
# 135  2018         app  poor security                 5  Bleeping Computer
# 157  2017  government  poor security                 5          The Local
# 168  2016        misc         hacked                 5       PanamaPapers
# 169  2016  government         hacked                 5        Trend Micro
# 178  2016      health     inside job                 5           BBC News
# 190  2016         web         hacked                 5     Digital trends
# 192  2015      health         hacked                 5    Computer Weekly
# 196  2015         web         hacked                 5       The Guardian
# 197  2015         web         hacked                 5       The Guardian
# 199  2015  government         hacked                 5           BBC News
# 204  2015         web         hacked                 5      The Intercept
# 228  2014     finance     inside job                 5      Security Week
# 249  2013  government     inside job                 5   Business Insider
# 277  2011      health    lost device                 5       Boston Globe
# 323  2008     finance         hacked                 5       The Register
# 331  2008  government    lost device                 5           BBC News
#
#                   city         country  latitude  longitude  \
# 4             Shanghai           China   31.2304   121.4737
# 29           Sammamish             USA   47.6163  -122.0356
# 61          Lake Worth             USA   26.6168   -80.0684
# 87           Stockholm          Sweden   59.3293    18.0686
# 113              Seoul     South Korea   37.5665   126.9780
# 135      San Francisco             USA   37.7749  -122.4194
# 157           Borlänge          Sweden   60.4849    15.4251
# 168        Panama City          Panama    8.9824   -79.5199
# 169             Manila     Philippines   14.5995   120.9842
# 178              Paris          France   48.8566     2.3522
# 190          Yuba City             USA   39.1404  -121.6169
# 192  Mountlake Terrace             USA   47.7915  -122.3076
# 196          Hong Kong       Hong Kong   22.3193   114.1694
# 197              Milan           Italy   45.4642     9.1900
# 199         Washington             USA   38.8951   -77.0369
# 204         Carrollton             USA   32.9756   -96.8892
# 228              Seoul     South Korea   37.5665   126.9780
# 249         Fort Meade             USA   39.1096   -76.7446
# 277     South Weymouth             USA   42.2209   -70.9410
# 323            Atlanta             USA   33.7490   -84.3880
# 331             London  United Kingdom   51.5074    -0.1278
#
#               coordinates       date
# 4     [31.2304, 121.4737] 2022-07-01
# 29   [47.6163, -122.0356] 2021-09-01
# 61    [26.6168, -80.0684] 2020-09-01
# 87     [59.3293, 18.0686] 2019-02-01
# 113    [37.5665, 126.978] 2019-08-01
# 135  [37.7749, -122.4194] 2018-06-01
# 157    [60.4849, 15.4251] 2017-07-01
# 168    [8.9824, -79.5199] 2016-04-01
# 169   [14.5995, 120.9842] 2016-04-01
# 178     [48.8566, 2.3522] 2016-06-01
# 190  [39.1404, -121.6169] 2016-09-01
# 192  [47.7915, -122.3076] 2015-03-01
# 196   [22.3193, 114.1694] 2015-12-01
# 197       [45.4642, 9.19] 2015-07-01
# 199   [38.8951, -77.0369] 2015-07-01
# 204   [32.9756, -96.8892] 2015-11-01
# 228    [37.5665, 126.978] 2014-01-01
# 249   [39.1096, -76.7446] 2013-06-01
# 277    [42.2209, -70.941] 2011-09-01
# 323     [33.749, -84.388] 2008-12-01
# 331    [51.5074, -0.1278] 2008-10-01

# %%
# Sector Records Lost Summary
sector_groupby = cleaned_dBreaches_df.groupby('sector')['records_lost'].describe()
sector_groupby
# Out:
#             count          mean           std        min         25%  \
# sector
# NGO           1.0  5.000000e+05           NaN   500000.0   500000.00
# academic     11.0  5.411818e+05  8.201417e+05    43000.0    73500.00
# app          16.0  3.148244e+07  4.967304e+07   309000.0   500000.00
# finance      34.0  2.232497e+07  5.087761e+07    34000.0   325000.00
# financial     4.0  1.266785e+08  2.488893e+08   133000.0  1218436.75
# gaming       15.0  1.496605e+07  2.255347e+07   200000.0  2645377.50
# government   35.0  2.147778e+07  9.260192e+07       30.0   265738.50
# health       37.0  2.500211e+06  4.036160e+06    34000.0   231400.00
# legal         1.0  4.101101e+06           NaN  4101101.0  4101101.00
# military      1.0  9.350000e+05           NaN   935000.0   935000.00
# misc         11.0  8.295580e+06  1.420255e+07   110000.0  1335000.00
# retail       36.0  2.499094e+07  6.555040e+07     1025.0   600000.00
# tech         21.0  5.653912e+07  1.358075e+08    50000.0   200000.00
# telecoms     18.0  3.324356e+07  1.167856e+08   113000.0   177500.00
# transport    15.0  1.207072e+07  2.366975e+07    10000.0   725000.00
# web          88.0  6.314765e+07  1.248606e+08    40000.0  3600000.00
#
#                    50%           75%          max
# sector
# NGO           500000.0  5.000000e+05     500000.0
# academic      146000.0  4.800000e+05    2200000.0
# app          2055000.0  5.175000e+07  150000000.0
# finance      2550000.0  5.975000e+06  220000000.0
# financial    3290593.0  1.287507e+08  500000000.0
# gaming       7000000.0  1.250000e+07   77000000.0
# government   3000000.0  6.250000e+06  550000000.0
# health       1000000.0  3.000000e+06   20000000.0
# legal        4101101.0  4.101101e+06    4101101.0
# military      935000.0  9.350000e+05     935000.0
# misc         2200000.0  1.055000e+07   49000000.0
# retail       4400000.0  2.066365e+07  383000000.0
# tech         3000000.0  2.200000e+07  533000000.0
# telecoms     2200000.0  9.675000e+06  500000000.0
# transport    4500000.0  1.250000e+07   94000000.0
# web         18000000.0  5.000000e+07  700000000.0

# %%
# Sector Data Sensitivity Summary
sector_sens_groupby = cleaned_dBreaches_df.groupby('sector')['data_sensitivity'].describe()
sector_sens_groupby
# Out:
#             count      mean       std  min   25%  50%   75%  max
# sector
# NGO           1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0
# academic     11.0  2.545455  0.820200  2.0  2.00  2.0  3.00  4.0
# app          16.0  2.000000  1.211060  1.0  1.00  2.0  2.25  5.0
# finance      34.0  2.647059  1.124988  1.0  2.00  3.0  3.00  5.0
# financial     4.0  3.000000  1.414214  2.0  2.00  2.5  3.50  5.0
# gaming       15.0  1.733333  0.961150  1.0  1.00  1.0  2.00  4.0
# government   35.0  2.571429  1.289909  1.0  2.00  2.0  3.50  5.0
# health       37.0  3.405405  1.141623  1.0  2.00  4.0  4.00  5.0
# legal         1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0
# military      1.0  3.000000       NaN  3.0  3.00  3.0  3.00  3.0
# misc         11.0  2.545455  1.368476  1.0  2.00  2.0  3.00  5.0
# retail       36.0  2.305556  0.980363  1.0  1.75  2.0  3.00  5.0
# tech         21.0  1.904762  1.135991  1.0  1.00  2.0  2.00  5.0
# telecoms     18.0  1.777778  0.942809  1.0  1.00  1.5  2.00  4.0
# transport    15.0  2.133333  0.833809  1.0  2.00  2.0  2.50  4.0
# web          88.0  1.886364  1.207561  1.0  1.00  1.0  2.00  5.0

# %%
# Sector + Data Sensitivity Summary
sector_sens_index = cleaned_dBreaches_df.groupby(['sector', 'data_sensitivity'])['records_lost'].describe()
sector_sens_index
# Out:
#                              count          mean           std          min  \
# sector     data_sensitivity
# NGO        4                   1.0  5.000000e+05           NaN     500000.0
# academic   2                   7.0  1.847143e+05  2.561066e+05      43000.0
#            3                   2.0  1.130000e+06  1.371787e+06     160000.0
#            4                   2.0  1.200000e+06  1.414214e+06     200000.0
# app        1                   7.0  4.717143e+07  6.400083e+07     500000.0
#            2                   5.0  3.763800e+06  5.790264e+06     309000.0
#            3                   2.0  2.650000e+07  3.323402e+07    3000000.0
#            4                   1.0  1.700000e+06           NaN    1700000.0
#            5                   1.0  1.000000e+08           NaN  100000000.0
# finance    1                   6.0  3.458333e+06  2.434423e+06     450000.0
#            2                   9.0  2.719389e+07  7.243563e+07     125000.0
#            3                  12.0  2.703700e+07  4.671166e+07      34000.0
#            4                   5.0  2.952200e+07  6.344522e+07      40000.0
#            5                   2.0  1.075000e+07  1.308148e+07    1500000.0
# financial  2                   2.0  2.566968e+06  3.442151e+06     133000.0
#            3                   1.0  1.580249e+06           NaN    1580249.0
#            5                   1.0  5.000000e+08           NaN  500000000.0
# gaming     1                   8.0  1.403750e+07  2.569502e+07     200000.0
#            2                   4.0  1.932269e+07  2.635780e+07    1290755.0
#            3                   2.0  1.245000e+07  1.718269e+07     300000.0
#            4                   1.0  1.000000e+07           NaN   10000000.0
# government 1                   5.0  6.994895e+06  1.036102e+07     100000.0
#            2                  19.0  4.005837e+06  6.105315e+06      50500.0
#            3                   2.0  3.785000e+05  1.718269e+05     257000.0
#            4                   4.0  1.392950e+08  2.738219e+08         30.0
#            5                   5.0  1.654000e+07  2.309509e+07    1500000.0
# health     1                   2.0  5.550000e+06  6.293250e+06    1100000.0
#            2                   9.0  1.771698e+06  1.900559e+06      93689.0
#            3                   2.0  2.800000e+06  1.272792e+06    1900000.0
#            4                  20.0  2.262526e+06  4.649674e+06      34000.0
#            5                   4.0  3.653000e+06  5.018795e+06     112000.0
# legal      1                   1.0  4.101101e+06           NaN    4101101.0
# military   3                   1.0  9.350000e+05           NaN     935000.0
# misc       1                   2.0  2.570000e+07  3.295118e+07    2400000.0
#            2                   5.0  4.928275e+06  5.168308e+06     471376.0
#            3                   2.0  1.155000e+06  1.477853e+06     110000.0
#            5                   2.0  6.450000e+06  7.141778e+06    1400000.0
# retail     1                   9.0  5.009712e+06  9.085169e+06     150000.0
#            2                  10.0  1.221910e+07  1.933991e+07      97000.0
#            3                  15.0  4.782528e+07  9.731915e+07       1025.0
#            4                   1.0  1.630000e+04           NaN      16300.0
#            5                   1.0  1.500000e+07           NaN   15000000.0
# tech       1                  10.0  1.090932e+08  1.869268e+08      50000.0
#            2                   6.0  3.725000e+06  6.177358e+06      50000.0
#            3                   3.0  1.466667e+07  2.023199e+07    2000000.0
#            4                   1.0  2.240000e+06           NaN    2240000.0
#            5                   1.0  2.780000e+07           NaN   27800000.0
# telecoms   1                   9.0  7.480778e+06  1.079941e+07     113000.0
#            2                   5.0  2.331400e+06  3.702476e+06     130000.0
#            3                   3.0  6.466667e+06  7.392789e+06    2000000.0
#            4                   1.0  5.000000e+08           NaN  500000000.0
# transport  1                   3.0  1.133667e+07  9.860022e+06      10000.0
#            2                   8.0  5.406250e+06  6.524593e+06     700000.0
#            3                   3.0  3.447362e+07  5.172951e+07     420873.0
#            4                   1.0  3.800000e+05           NaN     380000.0
# web        1                  48.0  6.346946e+07  1.202632e+08     250000.0
#            2                  19.0  1.061408e+08  1.792916e+08      76000.0
#            3                   8.0  1.056162e+07  1.337749e+07      40000.0
#            4                   9.0  3.619897e+07  5.306580e+07     790724.0
#            5                   4.0  2.087500e+07  3.287201e+07     500000.0
#
#                                       25%          50%           75%  \
# sector     data_sensitivity
# NGO        4                 5.000000e+05     500000.0  5.000000e+05
# academic   2                 7.250000e+04      74000.0  1.355000e+05
#            3                 6.450000e+05    1130000.0  1.615000e+06
#            4                 7.000000e+05    1200000.0  1.700000e+06
# app        1                 5.000000e+05    1700000.0  8.850000e+07
#            2                 4.000000e+05    1710000.0  2.400000e+06
#            3                 1.475000e+07   26500000.0  3.825000e+07
#            4                 1.700000e+06    1700000.0  1.700000e+06
#            5                 1.000000e+08  100000000.0  1.000000e+08
# finance    1                 1.375000e+06    4250000.0  4.875000e+06
#            2                 2.000000e+05    2500000.0  4.200000e+06
#            3                 3.750000e+05    2050000.0  2.537500e+07
#            4                 2.700000e+05    1600000.0  2.700000e+06
#            5                 6.125000e+06   10750000.0  1.537500e+07
# financial  2                 1.349984e+06    2566968.5  3.783953e+06
#            3                 1.580249e+06    1580249.0  1.580249e+06
#            5                 5.000000e+08  500000000.0  5.000000e+08
# gaming     1                 3.125000e+06    6000000.0  8.450000e+06
#            2                 3.322689e+06    9000000.0  2.500000e+07
#            3                 6.375000e+06   12450000.0  1.852500e+07
#            4                 1.000000e+07   10000000.0  1.000000e+07
# government 1                 2.744770e+05    3600000.0  6.000000e+06
#            2                 1.300000e+05    3000000.0  5.095198e+06
#            3                 3.177500e+05     378500.0  4.392500e+05
#            4                 2.100075e+05    3590000.0  1.426750e+08
#            5                 1.700000e+06    3000000.0  2.150000e+07
# health     1                 3.325000e+06    5550000.0  7.775000e+06
#            2                 2.314000e+05    1023209.0  4.000000e+06
#            3                 2.350000e+06    2800000.0  3.250000e+06
#            4                 2.160278e+05     457165.0  1.625000e+06
#            5                 6.280000e+05    1750000.0  4.775000e+06
# legal      1                 4.101101e+06    4101101.0  4.101101e+06
# military   3                 9.350000e+05     935000.0  9.350000e+05
# misc       1                 1.405000e+07   25700000.0  3.735000e+07
#            2                 1.270000e+06    1800000.0  1.000000e+07
#            3                 6.325000e+05    1155000.0  1.677500e+06
#            5                 3.925000e+06    6450000.0  8.975000e+06
# retail     1                 6.000000e+05     900000.0  5.000000e+06
#            2                 4.122500e+05    3150000.0  1.045000e+07
#            3                 3.000000e+06    5000000.0  5.050000e+07
#            4                 1.630000e+04      16300.0  1.630000e+04
#            5                 1.500000e+07   15000000.0  1.500000e+07
# tech       1                 1.486895e+05    2700000.0  1.555000e+08
#            2                 1.250000e+05    1600000.0  3.000000e+06
#            3                 3.000000e+06    4000000.0  2.100000e+07
#            4                 2.240000e+06    2240000.0  2.240000e+06
#            5                 2.780000e+07   27800000.0  2.780000e+07
# telecoms   1                 2.000000e+05    2000000.0  1.000000e+07
#            2                 1.570000e+05     170000.0  2.500000e+06
#            3                 2.200000e+06    2400000.0  8.700000e+06
#            4                 5.000000e+08  500000000.0  5.000000e+08
# transport  1                 8.005000e+06   16000000.0  1.700000e+07
#            2                 2.512500e+06    3900000.0  4.925000e+06
#            3                 4.710436e+06    9000000.0  5.150000e+07
#            4                 3.800000e+05     380000.0  3.800000e+05
# web        1                 6.000000e+06   21000000.0  6.592500e+07
#            2                 5.000000e+06   24000000.0  9.575000e+07
#            3                 8.032500e+05    3000000.0  1.950000e+07
#            4                 3.000000e+06   17500000.0  4.000000e+07
#            5                 4.925000e+06    6500000.0  2.245000e+07
#
#                                      max
# sector     data_sensitivity
# NGO        4                    500000.0
# academic   2                    760000.0
#            3                   2100000.0
#            4                   2200000.0
# app        1                 150000000.0
#            2                  14000000.0
#            3                  50000000.0
#            4                   1700000.0
#            5                 100000000.0
# finance    1                   6300000.0
#            2                 220000000.0
#            3                 130000000.0
#            4                 143000000.0
#            5                  20000000.0
# financial  2                   5000937.0
#            3                   1580249.0
#            5                 500000000.0
# gaming     1                  77000000.0
#            2                  58000000.0
#            3                  24600000.0
#            4                  10000000.0
# government 1                  25000000.0
#            2                  26500000.0
#            3                    500000.0
#            4                 550000000.0
#            5                  55000000.0
# health     1                  10000000.0
#            2                   4500000.0
#            3                   3700000.0
#            4                  20000000.0
#            5                  11000000.0
# legal      1                   4101101.0
# military   3                    935000.0
# misc       1                  49000000.0
#            2                  11100000.0
#            3                   2200000.0
#            5                  11500000.0
# retail     1                  28000000.0
#            2                  57000000.0
#            3                 383000000.0
#            4                     16300.0
#            5                  15000000.0
# tech       1                 533000000.0
#            2                  16000000.0
#            3                  38000000.0
#            4                   2240000.0
#            5                  27800000.0
# telecoms   1                  32000000.0
#            2                   8700000.0
#            3                  15000000.0
#            4                 500000000.0
# transport  1                  18000000.0
#            2                  21000000.0
#            3                  94000000.0
#            4                    380000.0
# web        1                 700000000.0
#            2                 550000000.0
#            3                  35000000.0
#            4                 171000000.0
#            5                  70000000.0

# %%
# Unique Sectors
cleaned_dBreaches_df['sector'].unique()
# Out:
# array(['web', 'tech', 'financial', 'government', 'retail', 'NGO', 'misc',
#        'transport', 'legal', 'gaming', 'health', 'telecoms', 'app',
#        'finance', 'academic', 'military'], dtype=object)

# %%
# Sector Value Counts
cleaned_dBreaches_df['sector'].value_counts()
# Out:
# web           88
# health        37
# retail        36
# government    35
# finance       34
# tech          21
# telecoms      18
# app           16
# transport     15
# gaming        15
# misc          11
# academic      11
# financial      4
# NGO            1
# legal          1
# military       1
# Name: sector, dtype: int64

# %%
# Records Lost by Country
country_groupby = cleaned_dBreaches_df.groupby('country')['records_lost'].describe()
country_groupby
# Out:
#                       count          mean           std         min  \
# country
# Australia               4.0  3.493751e+07  6.937537e+07        30.0
# Belgium                 1.0  7.000000e+05           NaN    700000.0
# Brazil                  2.0  1.260000e+08  1.329361e+08  32000000.0
# Bulgaria                1.0  5.000000e+06           NaN   5000000.0
# Canada                  7.0  9.069000e+06  1.322808e+07    283000.0
# Chile                   1.0  6.000000e+06           NaN   6000000.0
# China                   4.0  1.371000e+08  2.425257e+08   2400000.0
# Estonia                 1.0  2.800000e+05           NaN    280000.0
# France                  6.0  2.406367e+07  3.781313e+07    112000.0
# Germany                 9.0  2.392222e+07  3.673288e+07   3300000.0
# Greece                  1.0  9.000000e+06           NaN   9000000.0
# Hong Kong               3.0  3.470000e+07  5.137305e+07   3700000.0
# India                   6.0  1.064868e+08  2.179439e+08    420873.0
# Indonesia               1.0  4.713760e+05           NaN    471376.0
# Israel                  4.0  2.555847e+07  4.455269e+07    450000.0
# Italy                   3.0  1.005433e+06  1.316734e+06     16300.0
# Japan                  12.0  4.143430e+06  6.109597e+06    133000.0
# Luxembourg              1.0  7.907240e+05           NaN    790724.0
# Netherlands             1.0  6.900000e+06           NaN   6900000.0
# Norway                  2.0  3.475000e+06  6.717514e+05   3000000.0
# Panama                  1.0  1.150000e+07           NaN  11500000.0
# Philippines             1.0  5.500000e+07           NaN  55000000.0
# Puerto Rico             1.0  3.980000e+05           NaN    398000.0
# Russia                  5.0  4.474364e+07  7.115860e+07   1500000.0
# Serbia                  1.0  5.190396e+06           NaN   5190396.0
# Singapore               1.0  1.500000e+06           NaN   1500000.0
# South Africa            1.0  2.400000e+07           NaN  24000000.0
# South Korea             7.0  1.554286e+07  6.818078e+06   8700000.0
# Sri Lanka               1.0  1.580249e+06           NaN   1580249.0
# Sweden                  4.0  3.300000e+06  2.706782e+06    500000.0
# Switzerland             1.0  5.000000e+05           NaN    500000.0
# Syria                   1.0  2.744770e+05           NaN    274477.0
# Taiwan                  1.0  3.000000e+06           NaN   3000000.0
# Turkey                  1.0  2.700000e+06           NaN   2700000.0
# USA                   213.0  3.961345e+07  1.031944e+08      1025.0
# United Arab Emirates    2.0  7.020000e+06  9.871211e+06     40000.0
# United Kingdom         32.0  5.122234e+06  1.077674e+07     10000.0
#
#                              25%          50%           75%          max
# country
# Australia               150007.5     375000.0  3.516250e+07  139000000.0
# Belgium                 700000.0     700000.0  7.000000e+05     700000.0
# Brazil                79000000.0  126000000.0  1.730000e+08  220000000.0
# Bulgaria               5000000.0    5000000.0  5.000000e+06    5000000.0
# Canada                 1750000.0    3700000.0  9.500000e+06   37000000.0
# Chile                  6000000.0    6000000.0  6.000000e+06    6000000.0
# China                  5100000.0   23000000.0  1.550000e+08  500000000.0
# Estonia                 280000.0     280000.0  2.800000e+05     280000.0
# France                  217500.0     435000.0  4.365000e+07   85200000.0
# Germany                5000000.0   16000000.0  2.000000e+07  120000000.0
# Greece                 9000000.0    9000000.0  9.000000e+06    9000000.0
# Hong Kong              5050000.0    6400000.0  5.020000e+07   94000000.0
# India                  7625000.0   17500000.0  4.125000e+07  550000000.0
# Indonesia               471376.0     471376.0  4.713760e+05     471376.0
# Israel                 2362500.0    4750000.0  2.794597e+07   92283889.0
# Italy                   258150.0     500000.0  1.500000e+06    2500000.0
# Japan                   687500.0    2405000.0  4.000000e+06   22000000.0
# Luxembourg              790724.0     790724.0  7.907240e+05     790724.0
# Netherlands            6900000.0    6900000.0  6.900000e+06    6900000.0
# Norway                 3237500.0    3475000.0  3.712500e+06    3950000.0
# Panama                11500000.0   11500000.0  1.150000e+07   11500000.0
# Philippines           55000000.0   55000000.0  5.500000e+07   55000000.0
# Puerto Rico             398000.0     398000.0  3.980000e+05     398000.0
# Russia                 8000000.0   18218203.0  2.500000e+07  171000000.0
# Serbia                 5190396.0    5190396.0  5.190396e+06    5190396.0
# Singapore              1500000.0    1500000.0  1.500000e+06    1500000.0
# South Africa          24000000.0   24000000.0  2.400000e+07   24000000.0
# South Korea           10550000.0   13200000.0  1.900000e+07   27800000.0
# Sri Lanka              1580249.0    1580249.0  1.580249e+06    1580249.0
# Sweden                 2150000.0    2850000.0  4.000000e+06    7000000.0
# Switzerland             500000.0     500000.0  5.000000e+05     500000.0
# Syria                   274477.0     274477.0  2.744770e+05     274477.0
# Taiwan                 3000000.0    3000000.0  3.000000e+06    3000000.0
# Turkey                 2700000.0    2700000.0  2.700000e+06    2700000.0
# USA                     500000.0    3900000.0  2.460000e+07  700000000.0
# United Arab Emirates   3530000.0    7020000.0  1.051000e+07   14000000.0
# United Kingdom          190000.0     950000.0  2.550000e+06   43500000.0

# %%
# Most Breaches by Organisation
cleaned_dBreaches_df['organisation'].value_counts()
# Out:
# Facebook                  5
# Citigroup                 3
# Twitter                   3
# AOL                       3
# Yahoo                     3
#                          ..
# Dixons Carphone           1
# Panerabread               1
# NMBS                      1
# Marriott International    1
# Ameritrade Inc.           1
# Name: organisation, Length: 323, dtype: int64

# %% [markdown]
# ## Exploratory Visualisations

# %%
# Create Pivot Table of Number of Data Breaches by Method per Year
dBreaches_year_pivot = cleaned_dBreaches_df.pivot_table('id',
                                                        aggfunc=np.size,
                                                        columns='method',
                                                        index=cleaned_dBreaches_df['year'],
                                                        fill_value=0)
dBreaches_year_pivot
# Out:
# method  accident  hacked  inside job  lost device  poor security
# year
# 2004           0       0           1            0              0
# 2005           0       0           0            2              0
# 2006           1       1           0            2              1
# 2007           0       3           2            5              0
# 2008           1       4           4           10              0
# 2009           0       6           0            0              0
# 2010           0       3           0            6              0
# 2011           1      18           0            9              0
# 2012           1      11           2            3              0
# 2013           3      20           2            4              0
# 2014           1      14           1            0              2
# 2015           1      18           0            0              3
# 2016           1      24           1            0              1
# 2017           1      13           0            1              1
# 2018           2      21           0            0             11
# 2019           1      29           1            0              7
# 2020           3      15           1            1              5
# 2021           0      25           0            0              3
# 2022           1       9           0            0              0

# %%
# Data Breach Methods Over Time (using pivot table)

# Set Colour Palette
#color = ['#730517', '#f44560', '#44d1df', '#32a4a7', '#1e7069']
color = ['#f8cd82', '#f65b74', '#f72078', '#23b0bd', '#0df7db']
#color = ['#a8216b', '#f1184c', '#f36943', '#f7dc66', '#2e9599']

# Create Pivot Table of Number of Data Breaches per Year
dBreaches_year_pivot = cleaned_dBreaches_df.pivot_table('id',
                                                   aggfunc=np.size,
                                                   columns='method',
                                                   index=cleaned_dBreaches_df['year'],
                                                   fill_value=0)

# Set Figure Parameters and Labels
dBreaches_year_pivot.plot(xticks=cleaned_dBreaches_df['year'].unique(),
                     rot=45,
                     figsize=(12,6),
                     subplots=False,
                     color = color,
                     layout=(1, 1),
                     sharex=False,
                     sharey=False,
                     xlabel='year',
                     ylabel="breaches",
                     title="Data Breach Methods Over Time",
                     fontsize=9)
# Out:
# <Axes: title={'center': 'Data Breach Methods Over Time'}, xlabel='year', ylabel='breaches'>

# %%
# Data Breach Methods Over Time (using Pivot Table) - Multiplots

# Set Colour Palette
#color = ['#730517', '#f44560', '#44d1df', '#32a4a7', '#1e7069']
color = ['#f8cd82', '#f65b74', '#f72078', '#23b0bd', '#0df7db']
#color = ['#a8216b', '#f1184c', '#f36943', '#f7dc66', '#2e9599']

# Create Pivot Table of Number of Data Breaches per Year
dBreaches_year_pivot = cleaned_dBreaches_df.pivot_table('id',
                                                   aggfunc=np.size,
                                                   columns='method',
                                                   index=cleaned_dBreaches_df['year'],
                                                   fill_value=0)

# Set Figure Parameters and Labels
dBreaches_year_pivot.plot(figsize=(12,6),
                     subplots=True,
                     color = color,
                     layout=(-1, 3),
                     sharex=False,
                     sharey=True,
                     xlabel='year',
                     ylabel="breaches",
                     title="Data Breach Methods Over Time")
# Out:
# array([[<Axes: xlabel='year', ylabel='breaches'>,
#         <Axes: xlabel='year', ylabel='breaches'>,
#         <Axes: xlabel='year', ylabel='breaches'>],
#        [<Axes: xlabel='year', ylabel='breaches'>,
#         <Axes: xlabel='year', ylabel='breaches'>,
#         <Axes: xlabel='year', ylabel='breaches'>]], dtype=object)

# %%
# Create Pivot Table of Total Data Breaches by Method
dBreaches_pivot = cleaned_dBreaches_df.pivot_table('id',
                                                   aggfunc='count',
                                                   #columns='sector',
                                                   index=cleaned_dBreaches_df['method'],
                                                   fill_value=0)
dBreaches_pivot
# Out:
#                 id
# method
# accident        18
# hacked         234
# inside job      15
# lost device     43
# poor security   34

# %%
# Total Data Breaches by Method

# Set Colour Palette
#color = ['#730517', '#f44560', '#44d1df', '#32a4a7', '#1e7069']
#color = ['#f8cd82', '#f65b74', '#f72078', '#23b0bd', '#0df7db']
#color = ['#a8216b', '#f1184c', '#f36943', '#f7dc66', '#2e9599']
#color = ['#7d3ac1','#af4bce','#db4cb2','#eb548c','#ea7369','#f0a58f','#fceae6']
color = ['#404788','#33638d','#287d8e','#1f968b','#29af7f']

# Create Pivot Table of Total Data Breaches by Method
dBreaches_pivot = cleaned_dBreaches_df.pivot_table(values='id',
                                                   aggfunc='count',
                                                   #columns='method',
                                                   index=cleaned_dBreaches_df['method'],
                                                   fill_value=0)

# Set Figure Parameters and Labels
dBreaches_pivot.plot.pie(y='id', autopct='%1.1f%%', startangle=90, legend=False, title='Data Breach Methods', ylabel='', colors=color)
# Out:
# <Axes: title={'center': 'Data Breach Methods'}>

# %%
# Create Pivot Table (Aggregate Function = Sum) of Breaches by Sector
dBreaches_sector_pivot = cleaned_dBreaches_df.pivot_table('id',
                                                          aggfunc=np.sum,
                                                          #columns='sector',
                                                          index='sector',
                                                          fill_value=0)
dBreaches_sector_pivot
# Out:
#                id
# sector
# NGO            11
# academic     3448
# app          2114
# finance      9392
# financial      40
# gaming       2981
# government   8623
# health       9901
# legal          24
# military      333
# misc         2168
# retail       6378
# tech         2783
# telecoms     4114
# transport    1521
# web         17909

# %%
# Total Records Lost by Sector

# Set Colour Palette
#color = ['#730517', '#f44560', '#44d1df', '#32a4a7', '#1e7069']
color = ['#f8cd82', '#f65b74', '#f72078', '#23b0bd', '#0df7db']
#color = ['#a8216b', '#f1184c', '#f36943', '#f7dc66', '#2e9599']

# Create Pivot Table (Aggregate Function = Sum)
dBreaches_sector_pivot = cleaned_dBreaches_df.pivot_table('records_lost',
                                                          aggfunc=np.sum,
                                                          #columns='data sensitivity',
                                                          index='sector',
                                                          fill_value=0)

# Set Figure Parameters and Labels
dBreaches_sector_pivot.plot.barh(figsize=(9,3),
                     subplots=False,
                     color = 'royalblue',
                     alpha=0.75,
                     layout=(-1, 3),
                     sharex=False,
                     sharey=False,
                     xlabel='records lost',
                     ylabel="sector",
                     legend=False,
                     title="Total Records Lost")
# Out:
# <Axes: title={'center': 'Total Records Lost'}, xlabel='records lost', ylabel='sector'>

# %%
# Create Pivot Table (Aggregate Function = Sum) of Total Number of Records Lost per Sector by Method
dBreaches_method_pivot = cleaned_dBreaches_df.pivot_table('records_lost',
                                                          aggfunc=np.sum,
                                                          columns='method',
                                                          index='sector',
                                                          fill_value=0)
dBreaches_method_pivot
# Out:
# method      accident      hacked  inside job  lost device  poor security
# sector
# NGO                0      500000           0            0              0
# academic       43000     1392000           0      4372000         146000
# app           500000   279910000           0            0      223309000
# finance       150000   694040000    36200000     14534000       14125000
# financial          0   506581186           0            0         133000
# gaming             0   224490755           0            0              0
# government  16140426   106498477     1589000     67994500      559500000
# health        550000    41346489      340000     27571311       22700000
# legal              0     4101101           0            0              0
# military           0      935000           0            0              0
# misc         2400000    24751376    12900000            0       51200000
# retail       7000000   838839528    13837405       897000       39100000
# tech         2400000   623871586           0       200000      560850000
# telecoms      170000   547101000     2000000     17113000       32000000
# transport     700000   156940000           0            0       23420873
# web         50000000  4492117613    92000000            0      922876000

# %%
# Total Records Lost by Method (Separate Charts)

# Set Colour Palette
#color = ['#730517', '#f44560', '#44d1df', '#32a4a7', '#1e7069']
color = ['#f8cd82', '#f65b74', '#f72078', '#23b0bd', '#0df7db']
#color = ['#a8216b', '#f1184c', '#f36943', '#f7dc66', '#2e9599']

# Create Pivot Table (Aggregate Function = Sum)
dBreaches_method_pivot = cleaned_dBreaches_df.pivot_table('records_lost',
                                                          aggfunc=np.sum,
                                                          columns='method',
                                                          index='sector',
                                                          fill_value=0)

# Set Figure Parameters and Labels
dBreaches_method_pivot.plot.barh(figsize=(6,16),
                     subplots=True,
                     color = 'royalblue',
                     alpha=0.75,
                     layout=(-1, 1),
                     sharex=False,
                     sharey=True,
                     xlabel='',
                     ylabel="sector",
                     legend=False)
                     #title="Total Records Lost")
# Out:
# array([[<Axes: title={'center': 'accident'}, ylabel='sector'>],
#        [<Axes: title={'center': 'hacked'}, ylabel='sector'>],
#        [<Axes: title={'center': 'inside job'}, ylabel='sector'>],
#        [<Axes: title={'center': 'lost device'}, ylabel='sector'>],
#        [<Axes: title={'center': 'poor security'}, ylabel='sector'>]],
#       dtype=object)

# %%
# Bubble Chart: Top 10 Breaches Over Time ('records lost' = Bubble Size) 

# Sort DataFrame based on 'records lost' column in Descending order
sorted_df = cleaned_dBreaches_df.sort_values(by=['records_lost'], ascending=False).head(10)

# Define Axes, Bubble Sizes and Legend Labels
x1 = sorted_df['year']
y1 =  sorted_df['data_sensitivity']
sizes1 = ((sorted_df['records_lost'])/75000)
label1 = sorted_df['organisation'].to_list()
legend_label1 = [f'{i}' for i in label1]


# Plot Figure
plt.figure(figsize=(15, 7))

# Set Figure Parameters
scatter1 = plt.scatter(x1, y1, 
                       s=sizes1, 
                       alpha=0.75, 
                       label=label1, 
                       c=np.arange(len(label1)), 
                       cmap='viridis')

# Customise Title, Legend and Axes Labels
plt.xlabel('year')
plt.ylabel('data_sensitivity')
plt.title('Top 10 Data Breaches')
plt.legend(handles=scatter1.legend_elements()[0],  # Get legend handles from scatter plot
           labels=legend_label1,
           title="organisations",
           loc='upper left')

# Show Figure
plt.show()

# %%
# Data Breach Severity

# Plot the records lost by data sensitivity
sens_records_lost = cleaned_dBreaches_df.groupby('data_sensitivity')['records_lost'].describe()
sens_records_lost_df = pd.DataFrame(sens_records_lost)

# Plot the data breach methods by year
method = cleaned_dBreaches_df.groupby(['method', 'year'])['records_lost'].count()
method_df = pd.DataFrame(method)
method_df = method_df.reset_index()
#method_df = method_df.set_index('method')
hacked = method_df.loc[method_df['method'] == 'hacked']

# Define x and y axes
x_bar = sens_records_lost_df.index
y_bar = sens_records_lost_df['count']

# Number of Subplots in Graph (1 row and 1 column -> so only 1 subplot)
fig, ax = plt.subplots(1, 1)

# Set colour of internal plot (gray)
ax = plt.gca()
ax.set_facecolor('#dfdfdf')

# Space between left- and right-outermost bars
#ax.axes.set_xlim(0.4,12.6)

# Set Colour Palette
color = ['#482677', '#404788', '#33638d', '#287d8e', '#1f968b']

# Plot Bar Graph
ax.bar(x_bar,y_bar, color=color, width=0.9, alpha=0.9, edgecolor='black')

# Set x-ticks on x-axis (show every Month)
plt.xticks(x_bar[::])

# Set Font
font = "Helvetica Neue"

# Set Title and Axes labels
ax.set_title('Data Breach Severity', fontname=font, fontsize=16)
ax.set_xlabel("data sensitivity", fontname=font, fontsize=12)
ax.set_ylabel("breaches", fontname=font, fontsize=12)

# Set the font for axis tick labels (i.e the numbers) to be Helvetica Neue
for tick in ax.get_xticklabels():
    tick.set_fontname(font)
for tick in ax.get_yticklabels():
    tick.set_fontname(font)

# Show plot
plt.show()

# %%
cleaned_dBreaches_df['sector'].unique()

# %% [markdown]
# ## Export DataFrame to CSV

# %%
# Export Summary DF to csv file
cleaned_dBreaches_df.to_csv('../Resources/complete_data_breaches.csv', index=False, header=True)
